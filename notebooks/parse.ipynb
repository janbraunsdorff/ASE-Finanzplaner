# %%
from csv import reader
import re



f = '/Users/janbraunsdorff/Downloads/gk.csv'

with open(f, 'r') as read_obj:
    for line in read_obj.readlines():
        atts = re.sub('[ ]+', ' ', line).split(';')
        date = atts[0].replace('"', '')
        cat = atts[9].replace('"', '')
        amount = atts[12].replace('"', '')

        thp = 'test'
        con = ''

        if 'ALDI' in cat:
            thp = 'Aldi'
            cat = 'Einkaufen - Discounter'
        
        if 'Penny' in cat:
            thp = 'Penny'
            cat = 'Einkaufen - Discounter'
        
        if 'MUELLER' in cat:
            thp = 'MUELLER'
            cat = 'Einkaufen - Drogerie'

        if 'DM Drogerie Markt' in cat:
            thp = 'DM Drogerie Markt'
            cat = 'Einkaufen - Drogerie'
        
        if 'APPLE.COM/BILL' in cat:
            thp = 'DM Drogerie Markt'
            cat = 'Einkaufen - Shopping'

        if 'Saturn' in cat:
            thp = 'Saturn'
            cat = 'Einkaufen - Elektronik'
        
        if 'SCHECK' in cat:
            thp = 'Scheck-In Center Durlach'
            cat = 'Einkaufen - Spupermarkt'

        if 'REWE' in cat:
            thp = 'Rewe'
            cat = 'Einkaufen - Spupermarkt'

        if 'Abrechnung' in cat:
            thp = 'Jan Braunsdorff'
            cat = 'Ausgleichszahlung'

        if 'DB' in cat:
            thp = 'Deutsche Bahn'
            cat = 'Fahrkarte'

        if 'AMZN' in cat:
            thp = 'Amazon Einkaufen'
            cat = 'Shopping'

        if 'SPOTIFY' in cat:
            thp = 'Paypal'
            cat = 'Spotify'
            con = '-con'

        if 'NETFLIX' in cat:
            thp = 'Paypal'
            cat = 'Netflix'
            con = '-con'

        if 'Netflix' in cat:
            thp = 'Laura Braunsdorff'
            cat = 'Netflix Sharing'

        if 'Miete Jan Braunsdorff Zimme' in cat:
            thp = 'Paul Beyer'
            cat = 'Miete'
            con = '-con'

        if 'Miete Jan Braunsdorff - Str' in cat:
            thp = 'Fam. Shell'
            cat = 'Miete'
            con = '-con'

        if 'VODAFONE' in cat:
            thp = 'Vodafone'
            cat = 'Internet'
            con = '-con'
        
        if 'NIKE' in cat:
            thp = 'Nike'
            cat = 'Shopping'

        if 'Kaution' in cat:
            thp = 'Fam. Shell'
            cat = 'Kaution'

        if 'Rundfunk' in cat:
            thp = 'ARD, ZDF'
            cat = 'Rundfunk'
            con = '-con'

        if 'Dauerauftragsgutschr' in cat:
            thp = 'Thomas Braunsdorff'
            cat = 'Kindergeld'
            con = '-con'

        if 'Gehalt' in cat:
            thp = 'Fiducia & GAD IT AG'
            cat = 'Gahlt'
            con = '-con'
        
        if '(Strom)' in cat:
            thp = 'E.on'
            cat = 'Strom'
            con = '-con'

        if 'TAKEAWAYCOM' in cat:
            thp = 'Lieferando'
            cat = 'Lieferdienst'

        if 'LS ' in cat:
            thp = 'Union Investment'
            cat = 'Altersvorsorge'



        print('touch -val -{} -thp {} -dat {} -cat {} {}'.format(amount, thp, date, cat, con))

    read_obj.close()
# Out:
# touch -val -890,00 -thp Fam. Shell -dat 01.10.2021 -cat Miete -con
# touch -val -56,80 -thp ARD, ZDF -dat 01.10.2021 -cat Rundfunk -con
# touch -val -3,58 -thp Rewe -dat 30.09.2021 -cat Einkaufen - Spupermarkt
# touch -val -19,99 -thp Vodafone -dat 30.09.2021 -cat Internet -con
# touch -val -333,26 -thp Jan Braunsdorff -dat 29.09.2021 -cat Ausgleichszahlung
# touch -val -4,60 -thp Deutsche Bahn -dat 28.09.2021 -cat Fahrkarte
# touch -val -45,00 -thp test -dat 27.09.2021 -cat Lastschrift-Kartenzahlung Am Karlstor/Karlsruhe/DE 24.09.2021 um 16:59:48 Uhr GA 66190000/00000076/00120326891484/2308793501/0/1222 REF 875809/260045
# touch -val -33,00 -thp Union Investment -dat 23.09.2021 -cat Altersvorsorge
# touch -val -48,00 -thp E.on -dat 22.09.2021 -cat Strom -con
# touch -val -4,60 -thp Deutsche Bahn -dat 20.09.2021 -cat Fahrkarte
# touch -val -4,60 -thp Deutsche Bahn -dat 17.09.2021 -cat Fahrkarte
